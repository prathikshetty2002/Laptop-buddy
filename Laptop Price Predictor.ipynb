# %%
import sys
sys.path
sys.path.append('/home/preetu/anaconda3/envs/preetu/lib/python3.8/site-packages')
import pandas as pd
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in /home/preetu/.local/lib/python3.8/site-packages (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: numpy>=1.17 in /home/preetu/.local/lib/python3.8/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)

# %%
data=pd.read_csv('datasets/laptop_data.csv')
data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data['Ram']= data['Ram'].str.replace('GB','')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
data['Weight']= data['Weight'].str.replace('kg','')

# %%
data['Price']= data['Price'].round()

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71379.0
# 1        Intel HD Graphics 6000  macOS   1.34   47896.0
# 2         Intel HD Graphics 620  No OS   1.86   30636.0
# 3            AMD Radeon Pro 455  macOS   1.83  135195.0
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96096.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
data['Ram']=data['Ram'].astype('int32')

# %%
data['Weight']=data['Weight'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.distplot(data['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-049e7ab17fe1> in <module>
# ----> 1 sns.distplot(data['Price'])
#
# NameError: name 'sns' is not defined

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['Company'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c029c64a35ec> in <module>
# ----> 1 sns.barplot(x=data['Company'],y=data['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['TypeName'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4ef88f793a1e> in <module>
# ----> 1 sns.barplot(x=data['TypeName'],y=data['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.distplot(data['Inches'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f22161575356> in <module>
# ----> 1 sns.distplot(data['Inches'])
#
# NameError: name 'sns' is not defined

# %%
sns.scatterplot(x=data['Inches'],y=data['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-caa6c9be4c75> in <module>
# ----> 1 sns.scatterplot(x=data['Inches'],y=data['Price'])
#
# NameError: name 'sns' is not defined

# %%
data['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
data['Touchscreen']=data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
data.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 419   Lenovo           Ultrabook    14.0
# 1093    Dell           Ultrabook    13.3
# 1298  Lenovo  2 in 1 Convertible    14.0
# 933   Lenovo  2 in 1 Convertible    13.3
# 564     Asus            Notebook    15.6
#
#                                 ScreenResolution                          Cpu  \
# 419                  IPS Panel Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 1093                 IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 933   IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 564                            Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 419     8             256GB SSD        AMD Radeon RX 550  Windows 10    1.75
# 1093    4             256GB SSD           AMD Radeon 530  Windows 10    1.40
# 1298    4             128GB SSD    Intel HD Graphics 520  Windows 10    1.80
# 933    16               1TB SSD  Intel Iris Graphics 540  Windows 10    1.30
# 564     8  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10    2.50
#
#         Price  Touchscreen
# 419   64755.0            0
# 1093  43602.0            0
# 1298  33993.0            1
# 933   95851.0            1
# 564   44702.0            0

# %%
data['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['Touchscreen'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-56e4c4348bb7> in <module>
# ----> 1 sns.barplot(x=data['Touchscreen'],y=data['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
data['Ips'] = data['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
data.sample(5)
# Out:
#        Company   TypeName  Inches             ScreenResolution  \
# 607     Lenovo   Notebook    15.6            Full HD 1920x1080
# 457  Microsoft  Ultrabook    13.5        Touchscreen 2256x1504
# 668    Toshiba   Notebook    15.6  IPS Panel Full HD 1920x1080
# 262         HP   Notebook    15.6  IPS Panel Full HD 1920x1080
# 62      Lenovo   Notebook    14.0  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram     Memory                    Gpu  \
# 607   Intel Core i5 7200U 2.5GHz    6    1TB HDD  Intel HD Graphics 620
# 457  Intel Core M m3-7Y30 2.2GHz    4  128GB SSD  Intel HD Graphics 615
# 668   Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
# 262   Intel Core i5 8250U 1.6GHz    4  500GB HDD  Intel HD Graphics 620
# 62    Intel Core i3 7130U 2.7GHz    8  256GB SSD  Intel HD Graphics 620
#
#             OpSys  Weight    Price  Touchscreen  Ips
# 607    Windows 10   2.400  30050.0            0    0
# 457  Windows 10 S   1.252  52694.0            1    0
# 668    Windows 10   2.000  67026.0            0    1
# 262    Windows 10   2.100  38468.0            0    1
# 62          No OS   1.700  31915.0            0    1

# %%
sns.barplot(x=data['Ips'],y=data['Price'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-59d9e81f10cb> in <module>
# ----> 1 sns.barplot(x=data['Ips'],y=data['Price'])
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
new=data['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
data['x_res']=new[0]
data['y_res']=new[1]

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71379.0            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47896.0            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.0            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96096.0            0    1
#
#                            x_res y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
data['x_res'] = data['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71379.0            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47896.0            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.0            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96096.0            0    1
#
#   x_res y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
data['x_res']=data['x_res'].astype('int32')
data['y_res']=data['y_res'].astype('int32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %%
data.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191227
# Ips            0.252208
# x_res          0.556530
# y_res          0.552809
# Name: Price, dtype: float64

# %%
data['ppi'] = (((data['x_res']**2) + (data['y_res']**2))**0.5/data['Inches']).astype('float').round(2)

# %%
data.corr()['ppi']
# Out:
# Inches        -0.414793
# Ram            0.303779
# Weight        -0.323223
# Price          0.473506
# Touchscreen    0.460582
# Ips            0.300888
# x_res          0.931220
# y_res          0.939367
# ppi            1.000000
# Name: ppi, dtype: float64

# %%
data.drop(columns=['ScreenResolution'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight     Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71379.0
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47896.0
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636.0
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195.0
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96096.0
#
#    Touchscreen  Ips  x_res  y_res     ppi
# 0            0    1   2560   1600  226.98
# 1            0    0   1440    900  127.68
# 2            0    0   1920   1080  141.21
# 3            0    1   2880   1800  220.53
# 4            0    1   2560   1600  226.98

# %%
data.drop(columns=['Inches','x_res','y_res'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71379.0            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47896.0            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.0            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96096.0            0    1
#
#       ppi
# 0  226.98
# 1  127.68
# 2  141.21
# 3  220.53
# 4  226.98

# %%
data['Cpu Name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71379.0            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47896.0            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.0            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96096.0            0    1
#
#       ppi       Cpu Name
# 0  226.98  Intel Core i5
# 1  127.68  Intel Core i5
# 2  141.21  Intel Core i5
# 3  220.53  Intel Core i7
# 4  226.98  Intel Core i5

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['Cpu brand'] = data['Cpu Name'].apply(fetch_processor)

# %%
data.sample(20)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 1116  Lenovo              Gaming           Intel Core i7 6820HK 2.7GHz   16
# 496   Lenovo            Notebook            Intel Core i7 8550U 1.8GHz    8
# 333   Lenovo            Notebook              Intel Core i3 6006U 2GHz    4
# 382     Asus              Gaming           Intel Core i7 7700HQ 2.8GHz    8
# 1224    Dell  2 in 1 Convertible            Intel Core i3 7100U 2.4GHz    4
# 397   Lenovo            Notebook            Intel Core i5 7200U 2.5GHz    8
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 113       HP            Notebook            Intel Core i5 8250U 1.6GHz    4
# 682     Dell              Gaming           Intel Core i5 7300HQ 2.5GHz   16
# 330      MSI              Gaming           Intel Core i7 7700HQ 2.8GHz    8
# 223       HP            Notebook            Intel Core i5 8250U 1.6GHz    8
# 840     Asus              Gaming           Intel Core i7 6700HQ 2.6GHz   16
# 1293  Lenovo            Notebook           Intel Core i7 6700HQ 2.6GHz    8
# 471       HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 791     Vero            Notebook  Intel Celeron Dual Core N3350 1.1GHz    4
# 685     Dell              Gaming           Intel Core i7 7820HK 2.9GHz   16
# 54      Acer            Notebook            Intel Core i3 7100U 2.4GHz    4
# 561   Lenovo            Notebook            Intel Core i3 7130U 2.7GHz    4
# 820   Lenovo            Notebook              Intel Core i3 6006U 2GHz    4
# 1105    Dell           Ultrabook            Intel Core i5 6200U 2.3GHz    8
#
#                          Memory                         Gpu       OpSys  \
# 1116  256GB SSD +  1.0TB Hybrid     Nvidia GeForce GTX 980M  Windows 10
# 496                   256GB SSD      Intel UHD Graphics 620  Windows 10
# 333                     1TB HDD       Intel HD Graphics 520  Windows 10
# 382        128GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 1224                  500GB HDD       Intel HD Graphics 620  Windows 10
# 397                   256GB SSD       Intel HD Graphics 620  Windows 10
# 1269                  500GB HDD         Nvidia GeForce 920M  Windows 10
# 113                   500GB HDD      Intel UHD Graphics 620  Windows 10
# 682        128GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 330        256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10
# 223                     1TB HDD      Intel UHD Graphics 620  Windows 10
# 840        512GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 1293                    1TB HDD     Nvidia GeForce GTX 960M  Windows 10
# 471                   500GB HDD         AMD FirePro W4190M   Windows 10
# 791          32GB Flash Storage       Intel HD Graphics 500  Windows 10
# 685        256GB SSD +  1TB HDD     Nvidia GeForce GTX 1070  Windows 10
# 54                      1TB HDD       Intel HD Graphics 620  Windows 10
# 561                   128GB SSD       Intel HD Graphics 620  Windows 10
# 820                   500GB HDD       Intel HD Graphics 520  Windows 10
# 1105                  256GB SSD       Intel HD Graphics 520   Windows 7
#
#       Weight     Price  Touchscreen  Ips     ppi            Cpu Name  \
# 1116    4.60  146519.0            0    1  127.34       Intel Core i7
# 496     2.17   47893.0            0    0  141.21       Intel Core i7
# 333     1.85   23923.0            0    0  141.21       Intel Core i3
# 382     2.30   88178.0            0    1  141.21       Intel Core i7
# 1224    2.08   27120.0            1    0  146.86       Intel Core i3
# 397     1.90   49977.0            0    1  157.35       Intel Core i5
# 1269    2.20   38379.0            0    0  100.45       Intel Core i7
# 113     1.63   38468.0            0    1  111.94       Intel Core i5
# 682     3.21  109277.0            0    0  141.21       Intel Core i5
# 330     2.70   63883.0            0    0  127.34       Intel Core i7
# 223     2.10   42304.0            0    0  141.21       Intel Core i5
# 840     2.73   95851.0            0    0  127.34       Intel Core i7
# 1293    2.60   47899.0            0    1  141.21       Intel Core i7
# 471     1.90   61485.0            0    0  141.21       Intel Core i5
# 791     1.22   10811.0            0    0  157.35  Intel Celeron Dual
# 685     3.49  149917.0            0    0  141.21       Intel Core i7
# 54      2.40   20460.0            0    0  100.45       Intel Core i3
# 561     2.05   33566.0            0    0  141.21       Intel Core i3
# 820     2.10   26102.0            0    0  100.45       Intel Core i3
# 1105    1.50   75290.0            0    0  125.37       Intel Core i5
#
#                   Cpu brand
# 1116          Intel Core i7
# 496           Intel Core i7
# 333           Intel Core i3
# 382           Intel Core i7
# 1224          Intel Core i3
# 397           Intel Core i5
# 1269          Intel Core i7
# 113           Intel Core i5
# 682           Intel Core i5
# 330           Intel Core i7
# 223           Intel Core i5
# 840           Intel Core i7
# 1293          Intel Core i7
# 471           Intel Core i5
# 791   Other Intel Processor
# 685           Intel Core i7
# 54            Intel Core i3
# 561           Intel Core i3
# 820           Intel Core i3
# 1105          Intel Core i5

# %%
data.drop(columns=['Cpu Name'],inplace=True)
data.drop(columns=['Cpu'],inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight     Price  Touchscreen  Ips     ppi      Cpu brand
# 0  macOS    1.37   71379.0            0    1  226.98  Intel Core i5
# 1  macOS    1.34   47896.0            0    0  127.68  Intel Core i5
# 2  No OS    1.86   30636.0            0    0  141.21  Intel Core i5
# 3  macOS    1.83  135195.0            0    1  220.53  Intel Core i7
# 4  macOS    1.37   96096.0            0    1  226.98  Intel Core i5

# %%
data['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['Cpu brand'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-f3493c021eaf> in <module>
# ----> 1 sns.barplot(x=data['Cpu brand'],y=data['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
sns.barplot(x=data['Ram'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-dd9acf16245d> in <module>
# ----> 1 sns.barplot(x=data['Ram'],y=data['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
df = data
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-58-0a9b58fd0acc>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# <ipython-input-58-0a9b58fd0acc>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight     Price  Touchscreen  Ips     ppi      Cpu brand  HDD  SSD  \
# 0  macOS    1.37   71379.0            0    1  226.98  Intel Core i5    0  128
# 1  macOS    1.34   47896.0            0    0  127.68  Intel Core i5    0    0
# 2  No OS    1.86   30636.0            0    0  141.21  Intel Core i5    0  256
# 3  macOS    1.83  135195.0            0    1  220.53  Intel Core i7    0  512
# 4  macOS    1.37   96096.0            0    1  226.98  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0
# 3       0              0
# 4       0              0

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight     Price  Touchscreen  Ips     ppi      Cpu brand  HDD  SSD
# 0  macOS    1.37   71379.0            0    1  226.98  Intel Core i5    0  128
# 1  macOS    1.34   47896.0            0    0  127.68  Intel Core i5    0    0
# 2  No OS    1.86   30636.0            0    0  141.21  Intel Core i5    0  256
# 3  macOS    1.83  135195.0            0    1  220.53  Intel Core i7    0  512
# 4  macOS    1.37   96096.0            0    1  226.98  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-64b36af561ad> in <module>
# ----> 1 sns.barplot(x=df['Gpu'],y=df['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight     Price  Touchscreen  Ips     ppi      Cpu brand  HDD  SSD
# 0  macOS    1.37   71379.0            0    1  226.98  Intel Core i5    0  128
# 1  macOS    1.34   47896.0            0    0  127.68  Intel Core i5    0    0
# 2  No OS    1.86   30636.0            0    0  141.21  Intel Core i5    0  256
# 3  macOS    1.83  135195.0            0    1  220.53  Intel Core i7    0  512
# 4  macOS    1.37   96096.0            0    1  226.98  Intel Core i5    0  256

# %%
df['Gpu brand']= df['Gpu'].apply(lambda x: x.split())

# %%
df['Gpu brand'] = df['Gpu brand'].apply(lambda x: x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight     Price  Touchscreen  Ips     ppi      Cpu brand  HDD  SSD  \
# 0  macOS    1.37   71379.0            0    1  226.98  Intel Core i5    0  128
# 1  macOS    1.34   47896.0            0    0  127.68  Intel Core i5    0    0
# 2  No OS    1.86   30636.0            0    0  141.21  Intel Core i5    0  256
# 3  macOS    1.83  135195.0            0    1  220.53  Intel Core i7    0  512
# 4  macOS    1.37   96096.0            0    1  226.98  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  OpSys  Weight     Price  \
# 0   Apple  Ultrabook    8            128 SSD  macOS    1.37   71379.0
# 1   Apple  Ultrabook    8  128 Flash Storage  macOS    1.34   47896.0
# 2      HP   Notebook    8            256 SSD  No OS    1.86   30636.0
# 3   Apple  Ultrabook   16            512 SSD  macOS    1.83  135195.0
# 4   Apple  Ultrabook    8            256 SSD  macOS    1.37   96096.0
#
#    Touchscreen  Ips     ppi      Cpu brand  HDD  SSD Gpu brand
# 0            0    1  226.98  Intel Core i5    0  128     Intel
# 1            0    0  127.68  Intel Core i5    0    0     Intel
# 2            0    0  141.21  Intel Core i5    0  256     Intel
# 3            0    1  220.53  Intel Core i7    0  512       AMD
# 4            0    1  226.98  Intel Core i5    0  256     Intel

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-c3df7ece08af> in <module>
# ----> 1 sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
#
# NameError: name 'sns' is not defined

# %%
df=df[df['Gpu brand']!='ARM']

# %%
df.head()
df1=df
df1.head()
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 437 kB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
file_name='laptopsdata.xlsx'
df1.to_excel(file_name)

# %%
# df.drop(columns=['Cpu Name','Sc?reenResolution','Cpu'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram             Memory  Weight     Price  Touchscreen  \
# 0   Apple  Ultrabook    8            128 SSD    1.37   71379.0            0
# 1   Apple  Ultrabook    8  128 Flash Storage    1.34   47896.0            0
# 2      HP   Notebook    8            256 SSD    1.86   30636.0            0
# 3   Apple  Ultrabook   16            512 SSD    1.83  135195.0            0
# 4   Apple  Ultrabook    8            256 SSD    1.37   96096.0            0
#
#    Ips     ppi      Cpu brand  HDD  SSD Gpu brand      OS
# 0    1  226.98  Intel Core i5    0  128     Intel   MacOS
# 1    0  127.68  Intel Core i5    0    0     Intel   MacOS
# 2    0  141.21  Intel Core i5    0  256     Intel  Others
# 3    1  220.53  Intel Core i7    0  512       AMD   MacOS
# 4    1  226.98  Intel Core i5    0  256     Intel   MacOS

# %%
df['OS'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-c4a1ee08615c> in <module>
# ----> 1 df['OS'].value_counts()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'OS'

# %%
def OS(name):
    if name=='Windows 10' or name=='Windows 7' or name=='Windows 10 S':
        return 'Windows'
    elif name=='macOS' or name=='Mac OS X':
        return 'MacOS'
    else:
        return 'Others'

# %%
df['OS']=df['OpSys'].apply(OS)
# Out:
# <ipython-input-76-a02dacda9e5e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OS']=df['OpSys'].apply(OS)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  OpSys  Weight     Price  \
# 0   Apple  Ultrabook    8            128 SSD  macOS    1.37   71379.0
# 1   Apple  Ultrabook    8  128 Flash Storage  macOS    1.34   47896.0
# 2      HP   Notebook    8            256 SSD  No OS    1.86   30636.0
# 3   Apple  Ultrabook   16            512 SSD  macOS    1.83  135195.0
# 4   Apple  Ultrabook    8            256 SSD  macOS    1.37   96096.0
#
#    Touchscreen  Ips     ppi      Cpu brand  HDD  SSD Gpu brand      OS
# 0            0    1  226.98  Intel Core i5    0  128     Intel   MacOS
# 1            0    0  127.68  Intel Core i5    0    0     Intel   MacOS
# 2            0    0  141.21  Intel Core i5    0  256     Intel  Others
# 3            0    1  220.53  Intel Core i7    0  512       AMD   MacOS
# 4            0    1  226.98  Intel Core i5    0  256     Intel   MacOS

# %%
df['OS'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['OpSys'],inplace=True)
# Out:
# <ipython-input-79-b4b9708ecded>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-aa4f4450a243> in <module>
# ----> 1 sns.heatmap(df.corr())
#
# NameError: name 'sns' is not defined

# %%
df.corr()
# Out:
#                   Ram    Weight     Price  Touchscreen       Ips       ppi  \
# Ram          1.000000  0.383362  0.742905     0.118875  0.207949  0.305704
# Weight       0.383362  1.000000  0.209867    -0.293004  0.018643 -0.321866
# Price        0.742905  0.209867  1.000000     0.192918  0.253320  0.475387
# Touchscreen  0.118875 -0.293004  0.192918     1.000000  0.148026  0.458566
# Ips          0.207949  0.018643  0.253320     0.148026  1.000000  0.299151
# ppi          0.305704 -0.321866  0.475387     0.458566  0.299151  1.000000
# HDD          0.095808  0.514147 -0.096891    -0.208766 -0.093588 -0.294696
# SSD          0.603379 -0.063818  0.670660     0.257577  0.225311  0.509444
#
#                   HDD       SSD
# Ram          0.095808  0.603379
# Weight       0.514147 -0.063818
# Price       -0.096891  0.670660
# Touchscreen -0.208766  0.257577
# Ips         -0.093588  0.225311
# ppi         -0.294696  0.509444
# HDD          1.000000 -0.400750
# SSD         -0.400750  1.000000

# %%
sns.distplot(np.log(df['Price']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-c1a82a4801f0> in <module>
# ----> 1 sns.distplot(np.log(df['Price']))
#
# NameError: name 'sns' is not defined

# %%
Y=np.log(df['Price'])
X=df.drop(columns=['Price','Memory'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips     ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.98
# 1      Apple           Ultrabook    8    1.34            0    0  127.68
# 2         HP            Notebook    8    1.86            0    0  141.21
# 3      Apple           Ultrabook   16    1.83            0    1  220.53
# 4      Apple           Ultrabook    8    1.37            0    1  226.98
# ...      ...                 ...  ...     ...          ...  ...     ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.35
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.05
# 1300  Lenovo            Notebook    2    1.50            0    0  111.94
# 1301      HP            Notebook    6    2.19            0    0  100.45
# 1302    Asus            Notebook    4    2.20            0    0  100.45
#
#                   Cpu brand   HDD  SSD Gpu brand       OS
# 0             Intel Core i5     0  128     Intel    MacOS
# 1             Intel Core i5     0    0     Intel    MacOS
# 2             Intel Core i5     0  256     Intel   Others
# 3             Intel Core i7     0  512       AMD    MacOS
# 4             Intel Core i5     0  256     Intel    MacOS
# ...                     ...   ...  ...       ...      ...
# 1298          Intel Core i7     0  128     Intel  Windows
# 1299          Intel Core i7     0  512     Intel  Windows
# 1300  Other Intel Processor     0    0     Intel  Windows
# 1301          Intel Core i7  1000    0       AMD  Windows
# 1302  Other Intel Processor   500    0     Intel  Windows
#
# [1302 rows x 12 columns]

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips     ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.98
# 1      Apple           Ultrabook    8    1.34            0    0  127.68
# 2         HP            Notebook    8    1.86            0    0  141.21
# 3      Apple           Ultrabook   16    1.83            0    1  220.53
# 4      Apple           Ultrabook    8    1.37            0    1  226.98
# ...      ...                 ...  ...     ...          ...  ...     ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.35
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.05
# 1300  Lenovo            Notebook    2    1.50            0    0  111.94
# 1301      HP            Notebook    6    2.19            0    0  100.45
# 1302    Asus            Notebook    4    2.20            0    0  100.45
#
#                   Cpu brand   HDD  SSD Gpu brand       OS
# 0             Intel Core i5     0  128     Intel    MacOS
# 1             Intel Core i5     0    0     Intel    MacOS
# 2             Intel Core i5     0  256     Intel   Others
# 3             Intel Core i7     0  512       AMD    MacOS
# 4             Intel Core i5     0  256     Intel    MacOS
# ...                     ...   ...  ...       ...      ...
# 1298          Intel Core i7     0  128     Intel  Windows
# 1299          Intel Core i7     0  512     Intel  Windows
# 1300  Other Intel Processor     0    0     Intel  Windows
# 1301          Intel Core i7  1000    0       AMD  Windows
# 1302  Other Intel Processor   500    0     Intel  Windows
#
# [1302 rows x 12 columns]

# %%
Y
# Out:
# 0       11.175759
# 1       10.776787
# 2       10.329931
# 3       11.814473
# 4       11.473103
#           ...
# 1298    10.433910
# 1299    11.288118
# 1300     9.409273
# 1301    10.614131
# 1302     9.886341
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
conda install -c conda-forge xgboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# # linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8073298731096157
# MAE 0.2101765344920628

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram   Memory  Weight    Price  Touchscreen  Ips     ppi  \
# 0   Apple  Ultrabook    8  128 SSD    1.37  71379.0            0    1  226.98
#
#        Cpu brand  HDD  SSD Gpu brand     OS
# 0  Intel Core i5    0  128     Intel  MacOS

# %% [markdown]
# # Ridge regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8127349077688298
# MAE 0.20926638306111142

# %% [markdown]
# # lasso regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8071872329816978
# MAE 0.21114186484967123

# %% [markdown]
# # KNN's

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.802198515134463
# MAE 0.19319663698652398

# %% [markdown]
# # Decision tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8374140761537017
# MAE 0.1846106458113546

# %% [markdown]
# # SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8081541160779785
# MAE 0.20235986447736462

# %% [markdown]
# # Random forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8846768667070111
# MAE 0.15965497354674563

# %% [markdown]
# # Extra trees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15,
                              bootstrap=True)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8863315043843281
# MAE 0.16004866409613455

# %% [markdown]
# # Ada boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.7947470364467975
# MAE 0.2328560501083803

# %% [markdown]
# # Gradient boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8828319173561239
# MAE 0.1591519860630506

# %% [markdown]
# # Xgboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8811771030435894
# MAE 0.16496150405391416

# %% [markdown]
# # Voting regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.891196809958744
# MAE 0.15617812910025802

# %% [markdown]
# # Stacking regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15),),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,Y_pred))
print('MAE',mean_absolute_error(Y_test,Y_pred))
# Out:
# R2 score 0.8797841263309385
# MAE 0.16794626309645244

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight    Price  Touchscreen  Ips     ppi  \
# 0   Apple  Ultrabook    8    1.37  71379.0            0    1  226.98
#
#        Cpu brand  HDD  SSD Gpu brand     OS
# 0  Intel Core i5    0  128     Intel  MacOS

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
